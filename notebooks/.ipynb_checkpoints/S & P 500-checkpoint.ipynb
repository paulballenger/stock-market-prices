# %% [markdown]
# ## Can recent performance can predict stock movements?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %matplotlib inline

# %%
#import ^GSPC.csv file (from Yahoo Finance)
prices = pd.read_csv('../data/test.csv')
prices.head()
# Out:
#         Date     Open     High      Low    Close   Gain  % Gain
# 0  1/22/2018  2809.16  2833.03  2808.12  2832.97  23.81  0.0085
# 1  1/23/2018  2835.05  2842.24  2830.59  2839.13   4.08  0.0014
# 2  1/24/2018  2845.42  2852.97  2824.81  2837.54  -7.88 -0.0028
# 3  1/25/2018  2846.24  2848.56  2830.94  2839.25  -6.99 -0.0025
# 4  1/26/2018  2847.48  2872.87  2846.18  2872.87  25.39  0.0089

# %%
#drop columns
prices = prices.drop(columns=['High','Low'])
prices.head()
# Out:
#         Date     Open    Close   Gain  % Gain
# 0  1/22/2018  2809.16  2832.97  23.81  0.0085
# 1  1/23/2018  2835.05  2839.13   4.08  0.0014
# 2  1/24/2018  2845.42  2837.54  -7.88 -0.0028
# 3  1/25/2018  2846.24  2839.25  -6.99 -0.0025
# 4  1/26/2018  2847.48  2872.87  25.39  0.0089

# %%
#rename columns
prices = prices.rename(columns = {'Date':'date', 'Open':'open', 'Close':'close', 'Gain': 'gain', '% Gain': 'x_gain'})
prices.head()
# Out:
#         date     open    close   gain  x_gain
# 0  1/22/2018  2809.16  2832.97  23.81  0.0085
# 1  1/23/2018  2835.05  2839.13   4.08  0.0014
# 2  1/24/2018  2845.42  2837.54  -7.88 -0.0028
# 3  1/25/2018  2846.24  2839.25  -6.99 -0.0025
# 4  1/26/2018  2847.48  2872.87  25.39  0.0089

# %%
prices['pos_neg'] = ''
for ind, row in prices.iterrows():
    if row['x_gain'] > 0:
            prices.loc[ind, 'pos_neg'] = 'pos'
    else:
        prices.loc[ind, 'pos_neg'] = 'neg'
prices.head()
# Out:
#         date     open    close   gain  x_gain pos_neg
# 0  1/22/2018  2809.16  2832.97  23.81  0.0085     pos
# 1  1/23/2018  2835.05  2839.13   4.08  0.0014     pos
# 2  1/24/2018  2845.42  2837.54  -7.88 -0.0028     neg
# 3  1/25/2018  2846.24  2839.25  -6.99 -0.0025     neg
# 4  1/26/2018  2847.48  2872.87  25.39  0.0089     pos

# %%
#y.groupby((y != y.shift()).cumsum()).cumcount() + 1
#https://stackoverflow.com/questions/27626542/counting-consecutive-positive-value-in-python-array

prices['streak'] = prices['pos_neg'].groupby((prices['pos_neg'] != prices['pos_neg'].shift()).cumsum()).cumcount() + 1
prices.head()
# Out:
#         date     open    close   gain  x_gain pos_neg  streak
# 0  1/22/2018  2809.16  2832.97  23.81  0.0085     pos       1
# 1  1/23/2018  2835.05  2839.13   4.08  0.0014     pos       2
# 2  1/24/2018  2845.42  2837.54  -7.88 -0.0028     neg       1
# 3  1/25/2018  2846.24  2839.25  -6.99 -0.0025     neg       2
# 4  1/26/2018  2847.48  2872.87  25.39  0.0089     pos       1

# %%
#Assign to groups when pos_neg changes
#https://stackoverflow.com/questions/60334671/pandas-dataframe-how-to-find-consecutive-rows-that-meet-some-conditions
prices['g'] = prices['pos_neg'].ne(prices['pos_neg'].shift()).cumsum()
prices.head()
# Out:
#         date     open    close   gain  x_gain pos_neg  streak  g
# 0  1/22/2018  2809.16  2832.97  23.81  0.0085     pos       1  1
# 1  1/23/2018  2835.05  2839.13   4.08  0.0014     pos       2  1
# 2  1/24/2018  2845.42  2837.54  -7.88 -0.0028     neg       1  2
# 3  1/25/2018  2846.24  2839.25  -6.99 -0.0025     neg       2  2
# 4  1/26/2018  2847.48  2872.87  25.39  0.0089     pos       1  3

# %%
#Use cumsum to find cummulative sums
#https://stackoverflow.com/questions/32890124/pandas-dataframe-running-sum-with-reset/32891081#32891081
prices['cum']= prices.groupby(['g'])['x_gain'].cumsum()
prices.head()
# Out:
#         date     open    close   gain  x_gain pos_neg  streak  g     cum
# 0  1/22/2018  2809.16  2832.97  23.81  0.0085     pos       1  1  0.0085
# 1  1/23/2018  2835.05  2839.13   4.08  0.0014     pos       2  1  0.0099
# 2  1/24/2018  2845.42  2837.54  -7.88 -0.0028     neg       1  2 -0.0028
# 3  1/25/2018  2846.24  2839.25  -6.99 -0.0025     neg       2  2 -0.0053
# 4  1/26/2018  2847.48  2872.87  25.39  0.0089     pos       1  3  0.0089

# %%
prices['c'] = prices.x_gain + prices.streak
prices.head()
# Out:
#         date     open    close   gain  x_gain pos_neg  streak  g     cum  \
# 0  1/22/2018  2809.16  2832.97  23.81  0.0085     pos       1  1  0.0085
# 1  1/23/2018  2835.05  2839.13   4.08  0.0014     pos       2  1  0.0099
# 2  1/24/2018  2845.42  2837.54  -7.88 -0.0028     neg       1  2 -0.0028
# 3  1/25/2018  2846.24  2839.25  -6.99 -0.0025     neg       2  2 -0.0053
# 4  1/26/2018  2847.48  2872.87  25.39  0.0089     pos       1  3  0.0089
#
#         c
# 0  1.0085
# 1  2.0014
# 2  0.9972
# 3  1.9975
# 4  1.0089

# %%
prices['cum'].min()
# Out:
# -0.0503

# %%
#assign to bins based on % Gain and streak
prices['new_col'] = ''
for ind, row in prices.iterrows():
    if row['x_gain'] > 0 and row['x_gain'] < 0.0025 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'A'
    elif row['x_gain'] >= 0.0025 and row['x_gain'] < 0.0050 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'B'
    elif row['x_gain'] >= 0.0050 and row['x_gain'] < 0.0075 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'C'
    elif row['x_gain'] >= 0.0075 and row['x_gain'] < 0.0100 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'D'
    elif row['x_gain'] >= 0.0100 and row['x_gain'] < 0.0125 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'E'
    elif row['x_gain'] >= 0.0125 and row['x_gain'] < 0.0150 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'F'
    elif row['x_gain'] >= 0.0150 and row['x_gain'] < 0.0175 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'G'
    elif row['x_gain'] >= 0.0175 and row['x_gain'] < 0.0200 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'H'
    elif row['x_gain'] >= 0.0200 and row['x_gain'] < 0.0225 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'I'
    elif row['x_gain'] >= 0.0225 and row['x_gain'] < 0.0250 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'J'
    elif row['x_gain'] >= 0.0250 and row['x_gain'] < 0.0275 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'K'
    elif row['x_gain'] >= 0.0275 and row['x_gain'] < 0.0300 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'L'
    elif row['x_gain'] >= 0.0300 and row['x_gain'] < 0.0325 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'M'
    elif row['x_gain'] >= 0.0325 and row['x_gain'] < 0.0350 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'N'
    elif row['x_gain'] >= 0.0350 and row['x_gain'] < 0.0375 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'O'
    elif row['x_gain'] >= 0.0375 and row['x_gain'] < 0.0400 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'P'
    elif row['x_gain'] >= 0.0400 and row['x_gain'] < 0.0425 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'Q'
    elif row['x_gain'] >= 0.0425 and row['x_gain'] < 0.0450 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'R'
    elif row['x_gain'] >= 0.0475 and row['x_gain'] < 0.0500 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'S'
    elif row['x_gain'] >= 0.0500 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = 'T'
    elif row['x_gain'] > 0 and row['x_gain'] < 0.0025 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'A2'
    elif row['x_gain'] >= 0.0025 and row['x_gain'] < 0.0050 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'B2'
    elif row['x_gain'] >= 0.0050 and row['x_gain'] < 0.0075 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'C2'
    elif row['x_gain'] >= 0.0075 and row['x_gain'] < 0.0100 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'D2'
    elif row['x_gain'] >= 0.0100 and row['x_gain'] < 0.0125 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'E2'
    elif row['x_gain'] >= 0.0125 and row['x_gain'] < 0.0150 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'F2'
    elif row['x_gain'] >= 0.0150 and row['x_gain'] < 0.0175 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'G2'
    elif row['x_gain'] >= 0.0175 and row['x_gain'] < 0.0200 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'H2'
    elif row['x_gain'] >= 0.0200 and row['x_gain'] < 0.0225 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'I2'
    elif row['x_gain'] >= 0.0225 and row['x_gain'] < 0.0250 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'J2'
    elif row['x_gain'] >= 0.0250 and row['x_gain'] < 0.0275 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'K2'
    elif row['x_gain'] >= 0.0275 and row['x_gain'] < 0.0300 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'L2'
    elif row['x_gain'] >= 0.0300 and row['x_gain'] < 0.0325 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'M2'
    elif row['x_gain'] >= 0.0325 and row['x_gain'] < 0.0350 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'N2'
    elif row['x_gain'] >= 0.0350 and row['x_gain'] < 0.0375 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'O2'
    elif row['x_gain'] >= 0.0375 and row['x_gain'] < 0.0400 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'P2'
    elif row['x_gain'] >= 0.0400 and row['x_gain'] < 0.0425 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'Q2'
    elif row['x_gain'] >= 0.0425 and row['x_gain'] < 0.0450 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'R2'
    elif row['x_gain'] >= 0.0475 and row['x_gain'] < 0.0500 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'S2'
    elif row['x_gain'] >= 0.0500 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = 'T2'
    elif row['x_gain'] > 0 and row['x_gain'] < 0.0025 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'A3'
    elif row['x_gain'] >= 0.0025 and row['x_gain'] < 0.0050 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'B3'
    elif row['x_gain'] >= 0.0050 and row['x_gain'] < 0.0075 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'C3'
    elif row['x_gain'] >= 0.0075 and row['x_gain'] < 0.0100 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'D2'
    elif row['x_gain'] >= 0.0100 and row['x_gain'] < 0.0125 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'E3'
    elif row['x_gain'] >= 0.0125 and row['x_gain'] < 0.0150 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'F3'
    elif row['x_gain'] >= 0.0150 and row['x_gain'] < 0.0175 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'G3'
    elif row['x_gain'] >= 0.0175 and row['x_gain'] < 0.0200 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'H3'
    elif row['x_gain'] >= 0.0200 and row['x_gain'] < 0.0225 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'I3'
    elif row['x_gain'] >= 0.0225 and row['x_gain'] < 0.0250 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'J3'
    elif row['x_gain'] >= 0.0250 and row['x_gain'] < 0.0275 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'K3'
    elif row['x_gain'] >= 0.0275 and row['x_gain'] < 0.0300 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'L3'
    elif row['x_gain'] >= 0.0300 and row['x_gain'] < 0.0325 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'M3'
    elif row['x_gain'] >= 0.0325 and row['x_gain'] < 0.0350 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'N3'
    elif row['x_gain'] >= 0.0350 and row['x_gain'] < 0.0375 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'O3'
    elif row['x_gain'] >= 0.0375 and row['x_gain'] < 0.0400 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'P3'
    elif row['x_gain'] >= 0.0400 and row['x_gain'] < 0.0425 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'Q3'
    elif row['x_gain'] >= 0.0425 and row['x_gain'] < 0.0450 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'R3'
    elif row['x_gain'] >= 0.0475 and row['x_gain'] < 0.0500 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'S3'
    elif row['x_gain'] >= 0.0500 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = 'T3'
    elif row['x_gain'] > 0 and row['x_gain'] < 0.0025 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'A4'
    elif row['x_gain'] >= 0.0025 and row['x_gain'] < 0.0050 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'B4'
    elif row['x_gain'] >= 0.0050 and row['x_gain'] < 0.0075 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'C4'
    elif row['x_gain'] >= 0.0075 and row['x_gain'] < 0.0100 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'D4'
    elif row['x_gain'] >= 0.0100 and row['x_gain'] < 0.0125 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'E4'
    elif row['x_gain'] >= 0.0125 and row['x_gain'] < 0.0150 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'F4'
    elif row['x_gain'] >= 0.0150 and row['x_gain'] < 0.0175 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'G4'
    elif row['x_gain'] >= 0.0175 and row['x_gain'] < 0.0200 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'H4'
    elif row['x_gain'] >= 0.0200 and row['x_gain'] < 0.0225 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'I4'
    elif row['x_gain'] >= 0.0225 and row['x_gain'] < 0.0250 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'J4'
    elif row['x_gain'] >= 0.0250 and row['x_gain'] < 0.0275 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'K4'
    elif row['x_gain'] >= 0.0275 and row['x_gain'] < 0.0300 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'L4'
    elif row['x_gain'] >= 0.0300 and row['x_gain'] < 0.0325 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'M4'
    elif row['x_gain'] >= 0.0325 and row['x_gain'] < 0.0350 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'N4'
    elif row['x_gain'] >= 0.0350 and row['x_gain'] < 0.0375 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'O4'
    elif row['x_gain'] >= 0.0375 and row['x_gain'] < 0.0400 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'P4'
    elif row['x_gain'] >= 0.0400 and row['x_gain'] < 0.0425 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'Q4'
    elif row['x_gain'] >= 0.0425 and row['x_gain'] < 0.0450 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'R4'
    elif row['x_gain'] >= 0.0475 and row['x_gain'] < 0.0500 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'S4'
    elif row['x_gain'] >= 0.0500 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = 'T4'
    elif row['x_gain'] > 0 and row['x_gain'] < 0.0025 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'A5'
    elif row['x_gain'] >= 0.0025 and row['x_gain'] < 0.0050 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'B5'
    elif row['x_gain'] >= 0.0050 and row['x_gain'] < 0.0075 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'C2'
    elif row['x_gain'] >= 0.0075 and row['x_gain'] < 0.0100 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'D5'
    elif row['x_gain'] >= 0.0100 and row['x_gain'] < 0.0125 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'E5'
    elif row['x_gain'] >= 0.0125 and row['x_gain'] < 0.0150 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'F5'
    elif row['x_gain'] >= 0.0150 and row['x_gain'] < 0.0175 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'G5'
    elif row['x_gain'] >= 0.0175 and row['x_gain'] < 0.0200 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'H5'
    elif row['x_gain'] >= 0.0200 and row['x_gain'] < 0.0225 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'I5'
    elif row['x_gain'] >= 0.0225 and row['x_gain'] < 0.0250 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'J5'
    elif row['x_gain'] >= 0.0250 and row['x_gain'] < 0.0275 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'K5'
    elif row['x_gain'] >= 0.0275 and row['x_gain'] < 0.0300 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'L5'
    elif row['x_gain'] >= 0.0300 and row['x_gain'] < 0.0325 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'M5'
    elif row['x_gain'] >= 0.0325 and row['x_gain'] < 0.0350 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'N5'
    elif row['x_gain'] >= 0.0350 and row['x_gain'] < 0.0375 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'O5'
    elif row['x_gain'] >= 0.0375 and row['x_gain'] < 0.0400 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'P5'
    elif row['x_gain'] >= 0.0400 and row['x_gain'] < 0.0425 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'Q5'
    elif row['x_gain'] >= 0.0425 and row['x_gain'] < 0.0450 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'R5'
    elif row['x_gain'] >= 0.0475 and row['x_gain'] < 0.0500 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'S5'
    elif row['x_gain'] >= 0.0500 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = 'T5'
    if row['x_gain'] > -0.00250 and row['x_gain'] < 0.0000 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-A'
    elif row['x_gain'] >= -0.0025 and row['x_gain'] < -0.0050 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-B'
    elif row['x_gain'] >= -0.0050 and row['x_gain'] < -0.0075 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-C'
    elif row['x_gain'] >= -0.0075 and row['x_gain'] < -0.0100 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-D'
    elif row['x_gain'] >= -0.0100 and row['x_gain'] < -0.0125 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-E'
    elif row['x_gain'] >= -0.0125 and row['x_gain'] < -0.0150 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-F'
    elif row['x_gain'] >= -0.0150 and row['x_gain'] < -0.0175 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-G'
    elif row['x_gain'] >= -0.0175 and row['x_gain'] < -0.0200 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-H'
    elif row['x_gain'] >= -0.0200 and row['x_gain'] < -0.0225 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-I'
    elif row['x_gain'] >= -0.0225 and row['x_gain'] < -0.0250 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-J'
    elif row['x_gain'] >= -0.0250 and row['x_gain'] < -0.0275 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-K'
    elif row['x_gain'] >= -0.0275 and row['x_gain'] < -0.0300 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-L'
    elif row['x_gain'] >= -0.0300 and row['x_gain'] < -0.0325 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-M'
    elif row['x_gain'] >= -0.0325 and row['x_gain'] < -0.0350 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-N'
    elif row['x_gain'] >= -0.0350 and row['x_gain'] < -0.0375 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-O'
    elif row['x_gain'] >= -0.0375 and row['x_gain'] < -0.0400 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-P'
    elif row['x_gain'] >= -0.0400 and row['x_gain'] < -0.0425 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-Q'
    elif row['x_gain'] >= -0.0425 and row['x_gain'] < -0.0450 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-R'
    elif row['x_gain'] >= -0.0475 and row['x_gain'] < -0.0500 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-S'
    elif row['x_gain'] >= -0.0500 and row['streak'] == 1:
            prices.loc[ind, 'bin'] = '-T'
    elif row['x_gain'] > -0 and row['x_gain'] < -0.0025 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = -'A2'
    elif row['x_gain'] >= -0.0025 and row['x_gain'] < -0.0050 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-B2'
    elif row['x_gain'] >= -0.0050 and row['x_gain'] < -0.0075 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-C2'
    elif row['x_gain'] >= -0.0075 and row['x_gain'] < -0.0100 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-D2'
    elif row['x_gain'] >= -0.0100 and row['x_gain'] < -0.0125 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-E2'
    elif row['x_gain'] >= -0.0125 and row['x_gain'] < -0.0150 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-F2'
    elif row['x_gain'] >= -0.0150 and row['x_gain'] < -0.0175 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-G2'
    elif row['x_gain'] >= -0.0175 and row['x_gain'] < -0.0200 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-H2'
    elif row['x_gain'] >= -0.0200 and row['x_gain'] < -0.0225 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-I2'
    elif row['x_gain'] >= -0.0225 and row['x_gain'] < -0.0250 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-J2'
    elif row['x_gain'] >= -0.0250 and row['x_gain'] < -0.0275 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-K2'
    elif row['x_gain'] >= -0.0275 and row['x_gain'] < -0.0300 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-L2'
    elif row['x_gain'] >= -0.0300 and row['x_gain'] < -0.0325 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-M2'
    elif row['x_gain'] >= -0.0325 and row['x_gain'] < -0.0350 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-N2'
    elif row['x_gain'] >= -0.0350 and row['x_gain'] < -0.0375 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-O2'
    elif row['x_gain'] >= -0.0375 and row['x_gain'] < -0.0400 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-P2'
    elif row['x_gain'] >= -0.0400 and row['x_gain'] < -0.0425 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-Q2'
    elif row['x_gain'] >= -0.0425 and row['x_gain'] < -0.0450 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-R2'
    elif row['x_gain'] >= -0.0475 and row['x_gain'] < -0.0500 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-S2'
    elif row['x_gain'] >= -0.0500 and row['streak'] == 2:
            prices.loc[ind, 'bin'] = '-T2'
    elif row['x_gain'] > -0 and row['x_gain'] < -0.0025 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-A3'
    elif row['x_gain'] >= -0.0025 and row['x_gain'] < -0.0050 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-B3'
    elif row['x_gain'] >= -0.0050 and row['x_gain'] < -0.0075 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-C3'
    elif row['x_gain'] >= -0.0075 and row['x_gain'] < -0.0100 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-D2'
    elif row['x_gain'] >= -0.0100 and row['x_gain'] < -0.0125 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-E3'
    elif row['x_gain'] >= -0.0125 and row['x_gain'] < -0.0150 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-F3'
    elif row['x_gain'] >= -0.0150 and row['x_gain'] < -0.0175 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-G3'
    elif row['x_gain'] >= -0.0175 and row['x_gain'] < -0.0200 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-H3'
    elif row['x_gain'] >= -0.0200 and row['x_gain'] < -0.0225 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-I3'
    elif row['x_gain'] >= -0.0225 and row['x_gain'] < -0.0250 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-J3'
    elif row['x_gain'] >= -0.0250 and row['x_gain'] < -0.0275 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-K3'
    elif row['x_gain'] >= -0.0275 and row['x_gain'] < -0.0300 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-L3'
    elif row['x_gain'] >= -0.0300 and row['x_gain'] < -0.0325 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-M3'
    elif row['x_gain'] >= -0.0325 and row['x_gain'] < -0.0350 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-N3'
    elif row['x_gain'] >= -0.0350 and row['x_gain'] < -0.0375 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-O3'
    elif row['x_gain'] >= -0.0375 and row['x_gain'] < -0.0400 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-P3'
    elif row['x_gain'] >= -0.0400 and row['x_gain'] < -0.0425 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-Q3'
    elif row['x_gain'] >= -0.0425 and row['x_gain'] < -0.0450 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-R3'
    elif row['x_gain'] >= -0.0475 and row['x_gain'] < -0.0500 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-S3'
    elif row['x_gain'] >= -0.0500 and row['streak'] == 3:
            prices.loc[ind, 'bin'] = '-T3'
    elif row['x_gain'] > -0 and row['x_gain'] < 0.0025 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-A4'
    elif row['x_gain'] >= -0.0025 and row['x_gain'] < -0.0050 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-B4'
    elif row['x_gain'] >= -0.0050 and row['x_gain'] < -0.0075 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-C4'
    elif row['x_gain'] >= -0.0075 and row['x_gain'] < -0.0100 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-D4'
    elif row['x_gain'] >= -0.0100 and row['x_gain'] < -0.0125 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-E4'
    elif row['x_gain'] >= -0.0125 and row['x_gain'] < -0.0150 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-F4'
    elif row['x_gain'] >= -0.0150 and row['x_gain'] < -0.0175 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-G4'
    elif row['x_gain'] >= -0.0175 and row['x_gain'] < -0.0200 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-H4'
    elif row['x_gain'] >= -0.0200 and row['x_gain'] < -0.0225 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-I4'
    elif row['x_gain'] >= -0.0225 and row['x_gain'] < -0.0250 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-J4'
    elif row['x_gain'] >= -0.0250 and row['x_gain'] < -0.0275 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-K4'
    elif row['x_gain'] >= -0.0275 and row['x_gain'] < -0.0300 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-L4'
    elif row['x_gain'] >= -0.0300 and row['x_gain'] < -0.0325 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-M4'
    elif row['x_gain'] >= -0.0325 and row['x_gain'] < -0.0350 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-N4'
    elif row['x_gain'] >= -0.0350 and row['x_gain'] < -0.0375 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-O4'
    elif row['x_gain'] >= -0.0375 and row['x_gain'] < -0.0400 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-P4'
    elif row['x_gain'] >= -0.0400 and row['x_gain'] < -0.0425 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-Q4'
    elif row['x_gain'] >= -0.0425 and row['x_gain'] < -0.0450 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-R4'
    elif row['x_gain'] >= -0.0475 and row['x_gain'] < -0.0500 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-S4'
    elif row['x_gain'] >= -0.0500 and row['streak'] == 4:
            prices.loc[ind, 'bin'] = '-T4'
    elif row['x_gain'] > -0 and row['x_gain'] < 0.0025 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-A5'
    elif row['x_gain'] >= -0.0025 and row['x_gain'] < -0.0050 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-B5'
    elif row['x_gain'] >= -0.0050 and row['x_gain'] < -0.0075 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-C2'
    elif row['x_gain'] >= -0.0075 and row['x_gain'] < -0.0100 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-D5'
    elif row['x_gain'] >= -0.0100 and row['x_gain'] < -0.0125 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-E5'
    elif row['x_gain'] >= -0.0125 and row['x_gain'] < -0.0150 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-F5'
    elif row['x_gain'] >= -0.0150 and row['x_gain'] < -0.0175 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-G5'
    elif row['x_gain'] >= -0.0175 and row['x_gain'] < -0.0200 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-H5'
    elif row['x_gain'] >= -0.0200 and row['x_gain'] < -0.0225 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-I5'
    elif row['x_gain'] >= -0.0225 and row['x_gain'] < -0.0250 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-J5'
    elif row['x_gain'] >= -0.0250 and row['x_gain'] < -0.0275 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-K5'
    elif row['x_gain'] >= -0.0275 and row['x_gain'] < -0.0300 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-L5'
    elif row['x_gain'] >= -0.0300 and row['x_gain'] < -0.0325 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-M5'
    elif row['x_gain'] >= -0.0325 and row['x_gain'] < -0.0350 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-N5'
    elif row['x_gain'] >= -0.0350 and row['x_gain'] < -0.0375 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-O5'
    elif row['x_gain'] >= -0.0375 and row['x_gain'] < -0.0400 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-P5'
    elif row['x_gain'] >= -0.0400 and row['x_gain'] < -0.0425 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-Q5'
    elif row['x_gain'] >= -0.0425 and row['x_gain'] < -0.0450 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-R5'
    elif row['x_gain'] >= -0.0475 and row['x_gain'] < -0.0500 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-S5'
    elif row['x_gain'] >= -0.0500 and row['streak'] == 5:
            prices.loc[ind, 'bin'] = '-T5'
    else:
        prices.loc[ind, 'bin'] ='z'
prices.head(25)
# Out:
#          date     open    close    gain  x_gain pos_neg  streak   g     cum  \
# 0   1/22/2018  2809.16  2832.97   23.81  0.0085     pos       1   1  0.0085
# 1   1/23/2018  2835.05  2839.13    4.08  0.0014     pos       2   1  0.0099
# 2   1/24/2018  2845.42  2837.54   -7.88 -0.0028     neg       1   2 -0.0028
# 3   1/25/2018  2846.24  2839.25   -6.99 -0.0025     neg       2   2 -0.0053
# 4   1/26/2018  2847.48  2872.87   25.39  0.0089     pos       1   3  0.0089
# 5   1/29/2018  2867.23  2853.53  -13.70 -0.0048     neg       1   4 -0.0048
# 6   1/30/2018  2832.74  2822.43  -10.31 -0.0036     neg       2   4 -0.0084
# 7   1/31/2018  2832.41  2823.81   -8.60 -0.0030     neg       3   4 -0.0114
# 8    2/1/2018  2816.45  2821.98    5.53  0.0020     pos       1   5  0.0020
# 9    2/2/2018  2808.92  2762.13  -46.79 -0.0167     neg       1   6 -0.0167
# 10   2/5/2018  2741.06  2648.94  -92.12 -0.0336     neg       2   6 -0.0503
# ...

# %% [markdown]
# ## Steps not needed currently

# %%
#find highest cummulative sums
#https://stackoverflow.com/questions/47924400/python-pandas-assign-last-value-of-dataframe-group-to-all-entries-of-that-group

prices['b_new'] = prices.groupby('g')['des'].transform('last')
prices.head()

# %%
#only keep highest cummulatives sums
prices['new_col'] = ''
for ind, row in prices.iterrows():
    if row['des'] == row['b_new']:
            prices.loc[ind, 'new_col'] = row['des']
    else:
        prices.loc[ind, 'new_col'] = ''
prices.head()

# %%
#drop unnecessary columns
prices = prices.drop(columns=['pos_neg','des','b_new','g'])
prices.head(25)

# %%
#could be helpful?

period = 5
prices['less_than_zero'] = (prices['% Gain']
                        .rolling(window=period, min_periods=period)
                        .agg(lambda x: (x < 0).sum()))

prices['greater_than_zero'] = (prices['% Gain']
                          .rolling(window=period,min_periods=period)
                          .agg(lambda x: (x > 0).sum()))
prices.head(25)
